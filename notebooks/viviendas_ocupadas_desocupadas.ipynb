# %% [markdown]
# # verificar datos de viviendas ocupadas y desocupadas desde 1993 hasta 2024

# %%
# !pip install openpyxl
# Out:
# ...
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
# abrir xlsx
import pandas as pd

ruta = '../data/processed/anexo-proyecciones-viviendas-dptal.xlsx'
df = pd.read_excel(ruta)

# wb.sheetnames
df.head()
# Out:
#    Código Departamento Nombre Departamento                               Área  \
# 0                    5           Antioquia                              Total
# 1                    5           Antioquia                           Cabecera
# 2                    5           Antioquia  Centros Poblados y Rural Disperso
# 3                    8           Atlántico                              Total
# 4                    8           Atlántico                           Cabecera
#
#       1993     1994     1995     1996     1997     1998     1999  ...  \
# 0  1026087  1057351  1088549  1119328  1149513  1178774  1207119  ...
# 1   720259   746829   773663   800443   826925   852917   878360  ...
# 2   305828   310522   314886   318885   322588   325857   328759  ...
# 3   298758   311464   323962   336140   347962   359382   370403  ...
# 4   278937   290946   302794   314401   325745   336800   347548  ...
#
# ...

# %%
# leer el nombre de las hojas
df = pd.read_excel(ruta, sheet_name='viviendas_ocupadas_dpto')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 35 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Código Departamento  99 non-null     int64
#  1   Nombre Departamento  99 non-null     object
#  2   Área                 99 non-null     object
#  3   1993                 99 non-null     int64
#  4   1994                 99 non-null     int64
#  5   1995                 99 non-null     int64
#  6   1996                 99 non-null     int64
#  7   1997                 99 non-null     int64
#  8   1998                 99 non-null     int64
#  9   1999                 99 non-null     int64
#  10  2000                 99 non-null     int64
#  11  2001                 99 non-null     int64
#  12  2002                 99 non-null     int64
#  13  2003                 99 non-null     int64
#  14  2004                 99 non-null     int64
# ...
